# %%
import webbrowser
import os
import boto3
import pyttsx3

engine = pyttsx3.init()
engine.setProperty('rate', 120)  # Speed of speech. Default is 200.
engine.setProperty('volume', 0.9)  # Volume level. Range is from 0.0 to 1.0.
engine.setProperty('voice', 'com.apple.speech.synthesis.voice.samantha')  # Voice selection.

engine.say("please enter choose your value:for running AWS press 1 for running google press 2 for running cgat GPT press 3 for running whatsapp press 4 for running gmail press 5 for running linkedin press 6 for running chrome press 7 for running calculator press 8 to launch ec2 instance press 9 to launch ec2 volume press 10 to launch API gateway press 11 for running youtube press 12 to run myntra press 13 to run government websites press 14 ")
engine.runAndWait()

print("welcome to my toolbox")
print("please choose one:")

print('''1. run AWS
    2.run google
    3.chat GTP
    4.run whatsapp
    5.run gmail
    6.run linkdin
    7.run chrome
    8.run calc
    9.launch ec2 instance
    10.launch ec2 volume 
    11.launch API GATEWAY
    12.run  youtube
    13.run myntra 
    14.run government websites
    15.run facebook
    16.run instgram
    ''')


x=int(input("enter what do you want"))
if x ==1:
        
    url='https://aws.amazon.com/'
    webbrowser.open(url)
elif x==2:
    
    url = 'https://www.google.com'  # Replace with the desired URL

    webbrowser.open(url)
elif x==3:
    url ="https://chat.openai.com/"
    webbrowser.open(url)
elif x==4:
    url ="https://www.whatsapp.com/"
    webbrowser.open(url)
elif x==5:
    url ="https://mail.google.com/?"
    webbrowser.open(url)
elif x==6:
    url ="https://www.linkedin.com/login?"
    webbrowser.open(url)
elif x==7:
    os.system("start chrome")
elif x==8:
    os.system("calc")
elif x==9:
    ec2=input("which service you want:")
    Az= input("please enter which Availability Zone:")
    OS_Images=input("which os you want:")
    instanceType=input("which instancetype you want:")
    maxCount=int(input("how many instance you want:"))
    myec2 = boto3.resource(ec2, Az)
    resource = myec2.create_instances(ImageId=OS_Images, InstanceType=instanceType, MaxCount=1, MinCount=1)
        # Open the AWS EC2 instance status page in a web browser
    url = 'https://ap-south-1.console.aws.amazon.com/ec2/home?region=ap-south-1#Instances:'
    webbrowser.open(url)
    
elif x==10:
    ec2volume=("ec2")
    Az= input("please enter which Availability Zone:")
    size=int(input("enter volume size:"))
    ec2 = boto3.client(ec2volume)
    resource = ec2.create_volume(AvailabilityZone=Az,Size=size)
    url = 'https://ap-south-1.console.aws.amazon.com/ec2/home?region=ap-south-1#Volumes:'
    webbrowser.open(url)
elif x==11:
          
    client = boto3.client('apigateway')
    api_name = input("enter api name:")
    api_description = input("enter api description ")

    response = client.create_rest_api(name=api_name,description=api_description)

    api_id = response['id']
    url = 'https://ap-south-1.console.aws.amazon.com/apigateway/main/apis?region=ap-south-1'
    webbrowser.open(url)
          
elif x==12:
    url ="https://www.youtube.com/"
    webbrowser.open(url)
elif x==13:
    url ="https://www.myntra.com/?utm_source=dms_google&utm_medium=searchbrand_cpc&utm_campaign=dms_google_searchbrand_cpc_Search_Brand_Myntra_Brand_India_BM_TROAS_SOK&gclid=Cj0KCQjwtO-kBhDIARIsAL6LorffVcuGJWTH9jf5piW4Zrk_zE9pXANjUgNpz_aKtTGN3215ertkubwaAsolEALw_wcB"
    webbrowser.open(url)
elif x==14:
    url ="https://www.mha.gov.in/en/other-government-websites"
    webbrowser.open(url)
elif x==15:
    url ="https://www.facebook.com/"
    webbrowser.open(url)
elif x==16:
    url ="https://www.instagram.com/?hl=en"
    webbrowser.open(url)
